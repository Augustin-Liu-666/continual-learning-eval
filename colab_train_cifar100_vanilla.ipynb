# %% [markdown]
# # 🚀 Continual Learning - Colab 示例
# 本示例用于在 Google Colab 上运行你的 `semantic_cifar100_vanilla.py` 脚本。

# %%
# 📦 克隆 GitHub 项目
# !git clone https://github.com/Augustin-Liu-666/continual-learning-eval.git
# %cd continual-learning-eval

# %%
# 🔧 添加项目根目录到 Python 路径，解决导入问题
import sys
sys.path.append('/content/continual-learning-eval')

# %%
# 🏃‍♂️ 运行 Vanilla 方法训练脚本
# !python semantic-cifar100/method-vanilla/semantic_cifar100_vanilla.py
