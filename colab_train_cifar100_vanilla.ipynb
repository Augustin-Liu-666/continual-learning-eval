# %% [markdown]
# # 🚀 Continual Learning - Colab Example
# This notebook runs the CIFAR-100 Vanilla baseline in Google Colab.

# %%
# 📦 Clone the GitHub repository
# !git clone https://github.com/Augustin-Liu-666/continual-learning-eval.git
# %cd continual-learning-eval

# %%
# 🔧 Add the repository root to the Python path
import sys
sys.path.append('/content/continual-learning-eval')

# %%
# 🏃‍♂️ Run the CIFAR-100 Vanilla baseline
# !PYTHONPATH=. python cifar100/method_vanilla/cifar100_vanilla.py --seed 0 --epochs 20
